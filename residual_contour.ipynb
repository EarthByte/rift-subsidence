# %%
# %matplotlib inline
import matplotlib.pyplot as plt

from tectonic_subsidence import TectonicSubsidence
from residual_contour import ResidualContour

fig, [[ax1, ax2], [ax3, ax4]] = plt.subplots(nrows=2, ncols=2,figsize=(16,12))

rc1 = ResidualContour(196, 90, 7, 'sunrise', 'Haq87_SealevelCurve_Longterm', 
                      'M6', 'parameters.json', 'my_results',
                        1., 1.301, 0.03, 90., 90.)
rc1.run()
cs1 = rc1.plot_residual_contour(ax1)
fig.colorbar(cs1,ax=ax1)


rc2 = ResidualContour(196, 90, 7, 'sunrise', 'Haq87_SealevelCurve_Longterm', 
                      'M7', 'parameters.json', 'my_results',
                        1., 1.301, 0.03, 90., 90.)
rc2.run()
cs2 = rc2.plot_residual_contour(ax2)
fig.colorbar(cs2,ax=ax2)


rc3 = ResidualContour(196, 90, 7, 'swift', 'Haq87_SealevelCurve_Longterm', 
                      'M6', 'parameters.json', 'my_results',
                        1., 1.301, 0.03, 90., 90.)
rc3.run()
cs3 = rc3.plot_residual_contour(ax3)
fig.colorbar(cs3,ax=ax3)


rc4 = ResidualContour(196, 90, 7, 'swift', 'Haq87_SealevelCurve_Longterm', 
                      'M7', 'parameters.json', 'my_results',
                        1., 1.301, 0.03, 90., 90.)
rc4.run()
cs4 = rc4.plot_residual_contour(ax4)
fig.colorbar(cs4,ax=ax4)

plt.show()
# Out:
# BETAs:  [1.   1.03 1.06 1.09 1.12 1.15 1.18 1.21 1.24 1.27 1.3 ]
# TBEG1s:  [196 189 182 175 168 161 154 147 140 133 126 119 112 105  98  91]
# The result shape:  (16, 11)
# durations: [106.  99.  92.  85.  78.  71.  64.  57.  50.  43.  36.  29.  22.  15.
#    8.   1.]
# BETAs:  [1.   1.03 1.06 1.09 1.12 1.15 1.18 1.21 1.24 1.27 1.3 ]
# TBEG1s:  [196 189 182 175 168 161 154 147 140 133 126 119 112 105  98  91]
# The result shape:  (16, 11)
# durations: [106.  99.  92.  85.  78.  71.  64.  57.  50.  43.  36.  29.  22.  15.
#    8.   1.]
# BETAs:  [1.   1.03 1.06 1.09 1.12 1.15 1.18 1.21 1.24 1.27 1.3 ]
# TBEG1s:  [196 189 182 175 168 161 154 147 140 133 126 119 112 105  98  91]
# The result shape:  (16, 11)
# durations: [106.  99.  92.  85.  78.  71.  64.  57.  50.  43.  36.  29.  22.  15.
#    8.   1.]
# BETAs:  [1.   1.03 1.06 1.09 1.12 1.15 1.18 1.21 1.24 1.27 1.3 ]
# TBEG1s:  [196 189 182 175 168 161 154 147 140 133 126 119 112 105  98  91]
# The result shape:  (16, 11)
# ...
